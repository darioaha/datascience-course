# %%
import numpy as np
import matplotlib as mpl
import pandas as pd

# %%
#file://localhost/path/to/table.csv.
df = pd.read_csv("E:/Users/Johana/Documents/DH/Trabajo Final/properatti.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail'],
#       dtype='object')

# %%
df.notnull().sum()
# Out:
# Unnamed: 0                    121220
# operation                     121220
# property_type                 121220
# place_name                    121197
# place_with_parent_names       121220
# country_name                  121220
# state_name                    121220
# geonames_id                   102503
# lat-lon                        69670
# lat                            69670
# lon                            69670
# price                         100810
# currency                      100809
# price_aprox_local_currency    100810
# price_aprox_usd               100810
# surface_total_in_m2            81892
# surface_covered_in_m2         101313
# price_usd_per_m2               68617
# price_per_m2                   87658
# floor                           7899
# rooms                          47390
# expenses                       14262
# properati_url                 121220
# description                   121218
# title                         121220
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                         0
# operation                          0
# property_type                      0
# place_name                        23
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    18717
# lat-lon                        51550
# lat                            51550
# lon                            51550
# price                          20410
# currency                       20411
# price_aprox_local_currency     20410
# price_aprox_usd                20410
# surface_total_in_m2            39328
# surface_covered_in_m2          19907
# price_usd_per_m2               52603
# price_per_m2                   33562
# floor                         113321
# rooms                          73830
# expenses                      106958
# properati_url                      0
# description                        2
# title                              0
# ...

# %%
#para probar que cada condición se cumple, dejo comentada cada linea
# a = df['price_usd_per_m2'].isnull()
# b = df['surface_covered_in_m2'].notnull()
# c = df['price_aprox_usd'].notnull()
mask1 = (df['price_usd_per_m2'].isnull())& (df['surface_covered_in_m2'].notnull()) & (df['price_aprox_usd'].notnull())
mask1.sum()
# Out:
# 24308

# %%
df1 = df[mask1]
mask1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e8bdddf6bc56> in <module>()
# ----> 1 df1 = df[mask1]
#       2 mask1
#
# NameError: name 'df' is not defined

# %%
x = df1['price_aprox_usd']/df1['surface_covered_in_m2']

# %%
df1.fillna({'price_usd_per_m2': x})
# Out:
#         Unnamed: 0 operation property_type             place_name  \
# 68              68      sell     apartment          Mar del Plata
# 77              77      sell     apartment          Mar del Plata
# 79              79      sell     apartment          Mar del Plata
# 87              87      sell         house                Córdoba
# 89              89      sell     apartment                Córdoba
# 92              92      sell     apartment                Córdoba
# 93              93      sell         house                Córdoba
# 94              94      sell            PH                Córdoba
# 95              95      sell         store                Córdoba
# 109            109      sell     apartment       Boulogne Sur Mer
# 111            111      sell            PH             San Isidro
# 112            112      sell     apartment             San Isidro
# 120            120      sell     apartment               Belgrano
# ...

# %%
#df1['price_usd_per_m2'] = df1.apply(x, axis = 1)

# %%
#df1.loc[mask1, 'price_usd_per_m2'] = df.loc[df1, 'price_usd_per_m2'].apply(lambda x:
                                                                        df['price_aprox_usd']/df['surface_covered_in_m2'])
