# %%
import pandas as pd
import numpy as np
import numpy as np
import re
import seaborn as sns
from scipy import stats
import math
import operator
import plotly
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.offline import init_notebook_mode, iplot, plot

# %%
# %matplotlib inline

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = 10, 10

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
import feather
df = feather.read_dataframe("E:/Users/Johana/Documents/DH/Trabajo Final/principal.feather")
df.sample(2)
# Out:
#        property_type                    lat-lon        lat        lon  \
# 65080              2                       None        NaN        NaN
# 2503               1  -34.42508698,-58.57965851 -34.425087 -58.579659
#
#           price  price_aprox_usd  surface_total_in_m2  surface_covered_in_m2  \
# 65080  150000.0         150000.0                250.0                  135.0
# 2503        NaN              NaN                 54.0                   45.0
#
#        price_usd_per_m2  price_per_m2  ambientes  provincia  partido  \
# 65080         600.00000   1111.111111        2.0        1.0     13.0
# 2503         2339.41615   3019.436777        2.0        0.0      8.0
#
#        localidad  condicion price_aprox_usd_levels
# 65080      257.0        NaN                      3
# 2503       220.0        NaN                    NaN

# %%
df.columns
# Out:
# Index(['property_type', 'lat-lon', 'lat', 'lon', 'price', 'price_aprox_usd',
#        'surface_total_in_m2', 'surface_covered_in_m2', 'price_usd_per_m2',
#        'price_per_m2', 'ambientes', 'provincia', 'partido', 'localidad',
#        'condicion', 'price_aprox_usd_levels'],
#       dtype='object')

# %%
#df = pd.read_csv("E:/Users/Johana/Documents/DH/Trabajo Final/properati_final.csv", sep = ",")
df.rename(columns={"Unnamed: 0": "indice"}, inplace=True)
#elimino las columnas que no vamos a usar
to_drop = [
            'price_usd_per_m2', 
            'price_per_m2', 
            'lat-lon', 
             'price',
            'surface_covered_in_m2',
            'condicion', 'price_aprox_usd_levels','localidad',
             'lat','lon'] 
df.drop(columns=to_drop, inplace=True) #aplicar drop
df.sample(2)
# Out:
#        property_type  price_aprox_usd  surface_total_in_m2  ambientes  \
# 1242               1        319589.29                136.0        5.0
# 31445              1        150000.00                 70.0        4.0
#
#        provincia  partido
# 1242         0.0      8.0
# 31445        1.0     18.0

# %%
df.isnull().sum()
# Out:
# property_type              0
# price_aprox_usd        23831
# surface_total_in_m2     9687
# ambientes              30280
# provincia                  0
# partido                 1904
# dtype: int64

# %%
columnas_principales = ['price_aprox_usd','surface_total_in_m2', 'ambientes','partido']

df = df.dropna(axis =0 , how = 'any', subset = columnas_principales)
df.shape
# Out:
# (72026, 6)

# %%
df.describe() # no tiene media 1 hay que normalizar
# Out:
#        property_type  price_aprox_usd  surface_total_in_m2     ambientes  \
# count   72026.000000     72026.000000         72026.000000  7.202600e+04
# mean        1.246078    189785.646636           132.347357  3.100455e+05
# std         0.562591    143277.417541           167.967029  8.320580e+07
# min         0.000000         0.000000             0.000000 -5.000000e+00
# 25%         1.000000     90000.000000            45.000000  2.000000e+00
# 50%         1.000000    140000.000000            73.000000  3.000000e+00
# 75%         2.000000    240000.000000           153.455330  4.000000e+00
# max         3.000000    815000.000000          1490.000000  2.233049e+10
#
#           provincia       partido
# count  72026.000000  72026.000000
# mean       4.382834    106.565935
# std        5.344558    120.164590
# min        0.000000      0.000000
# 25%        1.000000     14.000000
# 50%        3.000000     50.000000
# 75%        5.000000    154.000000
# max       27.000000    538.000000

# %%
print([df[col].var() for col in df.columns]) #la varianza de todas es muy diferente
# Out:
# [0.31650839264094544, 20528418377.30644, 28212.92282499679, 6923205065364738.0, 28.564300394725517, 14439.528571700535]

# %%
#reviso relación con alguna variable
sns.regplot(df.surface_total_in_m2, df.price_aprox_usd, order=1, ci=None, scatter_kws={'color':'r', 's':9})

# %%
#reviso distribución de variable dependiente

sns.distplot(df['price_aprox_usd'])

# %%
sns.pairplot(df)

# %%
#variable dependiente
#y = df.price_aprox_usd
y = pd.DataFrame(df.price_aprox_usd)
x =df[['property_type',  
       'surface_total_in_m2', 'ambientes',
       'provincia']]
# #variables explicativas
columnsx= [['property_type',  
       'surface_total_in_m2', 'ambientes',
       'provincia']]

# %%
x.head()
# Out:
#    property_type  surface_total_in_m2  ambientes  provincia  partido
# 0              0                 55.0        2.0        5.0    149.0
# 2              1                 55.0        2.0        5.0    149.0
# 3              0                  3.0        3.0        5.0    148.0
# 4              1                 35.0        2.0        3.0     50.0
# 8              1                 65.0        2.0        5.0    134.0

# %%
#pendiente definir necesidad de crear dummies
#df_dummies = pd.get_dummies(x, columns = [ 'provincia', 'partido', 'localidad', 'condicion'], drop_first = False)

# %%
#normalizo por min-max
from sklearn import preprocessing
minmaxscaler = preprocessing.MinMaxScaler()
x = minmaxscaler.fit_transform(x)
# Out:
# E:\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning:
#
# Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.

# %%
# from sklearn import preprocessing
# minmaxscaler = preprocessing.MinMaxScaler()
# x = df.values #returns a numpy array

# x_scaled = minmaxscaler.fit_transform(x)
# df = pd.DataFrame(x_scaled)

# %%
xs = pd.DataFrame(x, columns=columnsx)
xs.head()
# Out:
#   property_type surface_total_in_m2     ambientes provincia   partido
# 0      0.000000            0.036913  3.134727e-10  0.185185  0.276952
# 1      0.333333            0.036913  3.134727e-10  0.185185  0.276952
# 2      0.000000            0.002013  3.582546e-10  0.185185  0.275093
# 3      0.333333            0.023490  3.134727e-10  0.111111  0.092937
# 4      0.333333            0.043624  3.134727e-10  0.185185  0.249071

# %%
#para revisar colinealidad, veo la matriz decorrelacion. 
#si el % entre variables es muy alto es problema que contenga la explicacion de la otra y haya colinealidad
xs.corr()
# Out:
#                     property_type surface_total_in_m2 ambientes provincia  \
# property_type            1.000000            0.454047 -0.001630 -0.057056
# surface_total_in_m2      0.454047            1.000000 -0.002093 -0.111876
# ambientes               -0.001630           -0.002093  1.000000 -0.000964
# provincia               -0.057056           -0.111876 -0.000964  1.000000
# partido                 -0.105460           -0.134550 -0.001754  0.964607
#
#                       partido
# property_type       -0.105460
# surface_total_in_m2 -0.134550
# ambientes           -0.001754
# provincia            0.964607
# partido              1.000000

# %%
#hay colinealidad entre provincia y partido, elimino partido
xs.drop(columns='partido', inplace=True) #aplicar drop
xs.sample(2)
# Out:
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py:3812: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#       property_type surface_total_in_m2     ambientes provincia
# 49473      0.333333            0.034899  3.134727e-10  0.185185
# 8389       0.333333            0.026846  3.582546e-10  0.111111

# %%
xs.corr()
# Out:
#                     property_type surface_total_in_m2 ambientes provincia
# property_type            1.000000            0.454047 -0.001630 -0.057056
# surface_total_in_m2      0.454047            1.000000 -0.002093 -0.111876
# ambientes               -0.001630           -0.002093  1.000000 -0.000964
# provincia               -0.057056           -0.111876 -0.000964  1.000000

# %%
print([xs[col].mean() for col in xs.columns])
# Out:
# [0.4153592684121971, 0.0888237293222491, 1.388462573676832e-05, 0.16232718431919757]

# %%
# calculo el cuadrado de cada valor(fila) en esa columna, y sumo todos los cuadrados
print([xs[col].apply(lambda x: x**2).sum() for col in xs.columns])
# Out:
# [14959.111111111113, 1483.5504802082087, 1.0000000000363816, 4720.03840877915]

# %%
import statsmodels.api as sm
#agrego el intercepto
X_intercept = sm.add_constant(xs)

# Fit and summarize OLS model
model_intercept = sm.OLS(y, X_intercept)
model_intercept = model_intercept.fit()
print (model_intercept.summary())
predictions_intercept = model_intercept.predict(X_intercept)
# Out:
# E:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning:
#
# Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-32e6dcb20b5b> in <module>
#       3
#       4 # Fit and summarize OLS model
# ----> 5 model_intercept = sm.OLS(y, X_intercept)
#       6 model_intercept = model_intercept.fit()
#       7 print (model_intercept.summary())
#
# E:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# E:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 663                                   weights=weights, hasconst=hasconst, **kwargs)
#     664         nobs = self.exog.shape[0]
#     665         weights = self.weights
#
# E:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     177     """
#     178     def __init__(self, endog, exog, **kwargs):
# --> 179         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     180         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     181
#
# E:\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# E:\Anaconda3\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# E:\Anaconda3\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# E:\Anaconda3\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# E:\Anaconda3\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      78         # this has side-effects, attaches k_constant and const_idx
#      79         self._handle_constant(hasconst)
# ---> 80         self._check_integrity()
#      81         self._cache = resettable_cache()
#      82
#
# E:\Anaconda3\lib\site-packages\statsmodels\base\data.py in _check_integrity(self)
#     496                 (hasattr(endog, 'index') and hasattr(exog, 'index')) and
#     497                 not self.orig_endog.index.equals(self.orig_exog.index)):
# --> 498             raise ValueError("The indices for endog and exog are not aligned")
#     499         super(PandasData, self)._check_integrity()
#     500
#
# ValueError: The indices for endog and exog are not aligned

# %%
print(model.summary())

# %%
#Me genera una matrix polinomial, obtengo los Beta, cuando es necesario hacerlo?
# se hace despues de normalizar y antes de dividir los datos entre train y test?
X = PolynomialFeatures(2,include_bias=False,interaction_only=False).fit_transform(xs)
df.shape, X.shape

# %%
#Calculo de residuos

predictions_intercept_df = pd.DataFrame(predictions_intercept)
residuos_intercept = Y - predictions_intercept_df
print(residuos_intercept.mean())

#otra forma:
model_intercept.resid.mean()

# %%
#verifico la distribución y la media de los residuos.
sns.distplot(residuos)

# %%
#verifico homocedasticidad con base en p_value
#supuesto: Para cualquier valor de la variable explicativa, el error tienen la misma varianza
import statsmodels.stats.api as sms

resids_standardized = model_intercept.get_influence().resid_studentized_internal

resids = model_intercept.resid

bp_test = pd.DataFrame(sms.het_breuschpagan(resids, model_intercept.model.exog), 
                       columns=['value'],
                       index=['Lagrange multiplier statistic', 'p-value', 'f-value', 'f p-value'])


gq_test = pd.DataFrame(sms.het_goldfeldquandt(resids, model_intercept.model.exog)[:-1],
                       columns=['value'],
                       index=['F statistic', 'p-value'])

print('\n Breusch-Pagan test ----')
print(bp_test)
print('\n Goldfeld-Quandt test ----')
print(gq_test)

# %%
#verifico el R2 y el error de la regresion

rss = np.sum(model_intercept.resid**2)
print('rss: ' + str(rss))

# %%
#Divido los datos en train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=53)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# %%
#definimos Cv con un random antes de hacer cada particion 
CVL = KFold(n_splits=5, shuffle=True)

# %%
#genero la regresión lineal
lm = LinearRegression(fit_intercept=True)
lm.fit(X_train, y_train)
y = y_test
y_pred = lm.predict(X_test)
rmse_lineal = np.sqrt(mean_squared_error(y, y_pred))
rmse_lineal

# %%
#obtengo los coheficientes
lm.get_params()
lm.coef_

# %%
#genero la regresion de Ridge

alfas_ridge = np.linspace(0.001, 0.3, 300)
lm_ridge_cv= RidgeCV(alphas=alfas_ridge, cv=CVL, normalize=False, fit_intercept = True)
lm_ridge_cv.fit(X_train, y_train)
print('Alpha Ridge:', lm_ridge_cv.alpha_)   
#utilizo el alfa del paso anterior y  fiteo con un intercepto
y = y_train
model = Ridge(lm_ridge_cv.alpha_, normalize=False, fit_intercept = True)
model.fit(X_train, y_train)
y_pred = model.predict(X_train)
np.sqrt(mean_squared_error(y, y_pred))

# %%
#genero la regresion de Lasso

alfas_lasso = np.linspace(0.1, 0.5, 300)
lm_lasso_cv = LassoCV(alphas=alfas_lasso, cv=CVL, normalize=False, fit_intercept = True)
lm_lasso_cv.fit(X_train, y_train)
print('Alpha LASSO:', lm_lasso_cv.alpha_)

y = y_train
model = Ridge(lm_lasso_cv.alpha_, normalize=False, fit_intercept = True)
model.fit(X_train, y_train)
y_pred = model.predict(X_train)
np.sqrt(mean_squared_error(y, y_pred))

# %%
#comparamos el error de test con el error de training para veriicar el modelo con menor diferencia

#pendiente comparar los errores, los alpha y revisar los coheficientes finales.
