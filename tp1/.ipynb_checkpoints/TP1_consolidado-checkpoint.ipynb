# %%
import pandas as pd
import numpy as np
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import re
import seaborn as sns
from scipy import stats
import timeit

# %%
df = pd.read_csv("Data/properatti.csv", sep = ",")

# %%
# 0. Descripcion breve de las acciones de limpieza que se van a seguir
# url-de-la-issue

#Analisis de los datos: pueden quedar comentados o con prints pero en pocas lineas. Ejemplo
print("Analisis cantidad de precios nulos:",len(df.price_usd_per_m2.isnull()))
print("Cantidad de ...")
#etc

# Utilizar funciones en lo posible y variables auxiliares
def obtener_precio(row):
    print("Hacer algo con la row",row)
    return row+1

#ejecutar con sample para que no tarde tanto en verificar si nuestra funcion esta ok
df_precio_aux = df.sample(10).price_usd_per_m2.apply(obtener_precio)
#df_precio_aux = df.price_usd_per_m2.apply(obtener_precio) #luego quitar la ejecucion con sample

# Ahora df_precio_aux tiene los datos que tendremos que llevar a nuestro dataframe principal
df.price_usd_per_m2.update(df_precio_aux.price_per_m2)

#imprimir algun tipo de resultado del procesamiento realizado, y las columas actualizadas
# Out:
# Analisis cantidad de precios nulos: 121220
# Cantidad de ...
# Hacer algo con la row 2028.5714285714291
# Hacer algo con la row 1890.2439024390244
# Hacer algo con la row 2277.777777777778
# Hacer algo con la row 1000.0
# Hacer algo con la row 1166.6666666666667
# Hacer algo con la row 2280.701754385965
# Hacer algo con la row 1411.764705882353
# Hacer algo con la row nan
# Hacer algo con la row nan
# Hacer algo con la row 1891.447368421053
# 16530     2029.571429
# 75540     1891.243902
# 65868     2278.777778
# 26561     1001.000000
# 108324    1167.666667
# 75887     2281.701754
# 103940    1412.764706
# 22169             NaN
# 70780             NaN
# 28400     1892.447368
# Name: price_usd_per_m2, dtype: float64

# %%
# 1. Completar el precio por metro cuadrado en dolares mediante el valor de precio por metro cuadrado cuando el currency es usd
# https://gitlab.com/dsdh/properatti/issues/5
#uniques = df.currency.unique()
#uniques
print("Cantidad de precios USD nulos 1: ",len(df[df.price_usd_per_m2.isnull()==True]))
# condicion dolar 'USD'
usd = 'USD'; cond_currency_usd = (df.currency == usd)
# condicion dolar 'USD'
cond_notusdprice_m2 = df.price_usd_per_m2.isnull()
# condicion price_per_m2 definido
cond_price_m2 = df.price_per_m2.notnull()
#mascara
mask_price_1 = cond_currency_usd & cond_notusdprice_m2 & cond_price_m2
df_price = df[mask_price_1 == True]

print("----Cantidad a reemplazar: ",len(df_price))
df.price_usd_per_m2.update(df_price.price_per_m2)
print("Result ==> Cantidad de precios USD nulos luego: ",len(df[df.price_usd_per_m2.isnull()==True]))

#ejemplo
df.iloc[68]
# Out:
# Cantidad de precios USD nulos 1:  52603
# ----Cantidad a reemplazar:  21437
# Result ==> Cantidad de precios USD nulos luego:  31166
# Unnamed: 0                                                                   68
# operation                                                                  sell
# property_type                                                         apartment
# place_name                                                        Mar del Plata
# place_with_parent_names       |argentina|buenos aires costa atlántica|mar de...
# country_name                                                          Argentina
# state_name                                         Buenos Aires Costa Atlántica
# geonames_id                                                         3.43086e+06
# lat-lon                                                  -38.034794,-57.5416872
# lat                                                                    -38.0348
# lon                                                                    -57.5417
# price                                                                    235000
# currency                                                                    USD
# price_aprox_local_currency                                          4.14646e+06
# price_aprox_usd                                                          235000
# surface_total_in_m2                                                         NaN
# surface_covered_in_m2                                                        72
# price_usd_per_m2                                                        3263.89
# price_per_m2                                                            3263.89
# floor                                                                       NaN
# rooms                                                                         2
# expenses                                                                    NaN
# properati_url                 http://www.properati.com.ar/15bx4_venta_depart...
# description                   Cocina integrada con barra ,  horno y anafe .T...
# title                         EXCELENTE DEPARTAMENTO CON VISTA AL MAR Y AL GOLF
# image_thumbnail               https://thumbs4.properati.com/2/-WPR2ibAcpGmjF...
# Name: 68, dtype: object

# %%
# 2. Calcular precio por metro cuadrado a partir de superficie
# https://gitlab.com/dsdh/properatti/issues/2
print("Cantidad de precios USD nulos 2: ",len(df[df.price_usd_per_m2.isnull()==True]))
# condicion en mask1
mask1 = (df.price_usd_per_m2.isnull())& (df.surface_covered_in_m2.notnull()) & (df.price_aprox_usd.notnull())
df1 = df[mask1]

print("----Cantidad a reemplazar: ",len(df1))
# Tal vez deberia hacerse la superficie total no la cubierta
x = df1.price_aprox_usd/df1.surface_covered_in_m2
df.price_usd_per_m2.update(x)
print("Result ==> Cantidad de precios USD nulos luego: ",len(df[df.price_usd_per_m2.isnull()==True]))

#ejemplo
df.iloc[154]
# Out:
# Cantidad de precios USD nulos 2:  31166
# ----Cantidad a reemplazar:  2871
# Result ==> Cantidad de precios USD nulos luego:  28295
# Unnamed: 0                                                                  154
# operation                                                                  sell
# property_type                                                         apartment
# place_name                                                             Santa Fe
# place_with_parent_names                           |argentina|santa fe|santa fe|
# country_name                                                          Argentina
# state_name                                                             Santa Fe
# geonames_id                                                         3.83628e+06
# lat-lon                                                   -31.622319,-60.705482
# lat                                                                    -31.6223
# lon                                                                    -60.7055
# price                                                                   1.2e+06
# currency                                                                    ARS
# price_aprox_local_currency                                          1.18748e+06
# price_aprox_usd                                                         67300.4
# surface_total_in_m2                                                         NaN
# surface_covered_in_m2                                                        40
# price_usd_per_m2                                                        1682.51
# price_per_m2                                                              30000
# floor                                                                       NaN
# rooms                                                                         2
# expenses                                                                    NaN
# properati_url                 http://www.properati.com.ar/15d9u_venta_depart...
# description                   Corredor Responsable: Marcos Provvidenti - CCI...
# title                                    VENTA DEPARTAMENTO - OFERTA DE CONTADO
# image_thumbnail               https://thumbs4.properati.com/8/ZyUn7rNDU-63Qd...
# Name: 154, dtype: object

# %%
#7: Evaluamos si los tres tipos de propidad que existen son "house", "apartment" y "PH".
casas = df.loc[:,"property_type"] == "house"
print("Cantidad de casas: ",casas.sum())

apartamentos = df.loc[:,"property_type"] == "apartment"
print("Cantidad de apartamentos: ",apartamentos.sum())

ph = df.loc[:,"property_type"] == "PH"
print("Cantidad de ph: ", ph.sum())

tipopropiedad = casas & apartamentos & ph
print("Propiedad sin tipo: ",tipopropiedad.sum())
# Out:
# Cantidad de casas:  40268
# Cantidad de apartamentos:  71065
# Cantidad de ph:  5751
# Propiedad sin tipo:  0

# %%
df.place_with_parent_names = df.place_with_parent_names.map(str.lower) #llevo a minusculas para evitar duplicados
grouped_places = df.groupby(['place_with_parent_names']) #agrupo por place_with_parent_names
dictio_places = grouped_places.groups.keys() #genero diccionario de places
cantidad_places = len(dictio_places) #cuento la cantidad de places distintos
print("Cantidad de place_with_parent_names distintos: ",cantidad_places)

count_x_places = grouped_places.agg({"operation": "count"}) #agrupo y cuento
count_x_places = count_x_places.rename(index=str, columns={"operation": "cantidad"}) #renombro la columna por cantidad
count_x_places = count_x_places.sort_values(by=['cantidad'], ascending=False) #ordeno por cantidad descendente

len(count_x_places.query("cantidad > 50")) # places con mas de <n> registros. Solo consulta


list_places = [sub_places.split('|') for sub_places in count_x_places.index]

df_places = pd.DataFrame(list_places, 
                         index = count_x_places.index, 
                         columns =['none1','pais','provincia','partido','localidad','barrio','none2']) 

    
#df_places.groupby(['none1']).count() # agrupo por primer columna para ver si hay algo. rs: no hay
#df_places.groupby(['pais']).count() # agrupo por pais para ver si algo no es argentina. rs: no hay
# agrupo por barrio para ver si hay mucha data distinta. rs: no aporta informacion. muchos vacios. ver si rellenar con API de coordenadas
#df_places.groupby(['barrio']).count()

df_places = df_places.drop(['none1', 'none2'], axis=1) # elimino none1 y none2
# Para cada columna busco vacios y asigno None
for column_name in df_places.columns:
    df_places[column_name][df_places[column_name].apply(lambda column_name: True if re.search('^\s*$', str(column_name)) else False)]=None

df_places = df_places.sort_values(by=['provincia','partido','localidad','barrio']) #ordeno
#df_places.where('provicia == capital');
df_places[(df_places.provincia == "capital federal")]

len(df_places.partido.unique())
#df_places.sample(20)

#analizar porque hay duplicados en true
#count_x_places.duplicated()

len(df_places.partido)
# Out:
# Cantidad de place_with_parent_names distintos:  1164
# 1164

# %%
#q1_peso_usd_m2 = np.mean(price_usd_per_m2_arr) + 1*np.std(price_usd_per_m2_arr)
#q3_peso_usd_m2 = np.mean(price_usd_per_m2_arr) + 3*np.std(price_usd_per_m2_arr)

df_aux = df[df.price_usd_per_m2.notnull()] #elimino los nulos
q1_usd_m2, q3_usd_m2= np.percentile(df_aux.price_usd_per_m2,[25,75]) # obtengo q1 y q3
iqr_peso_usd_m2 = q3_usd_m2 - q1_usd_m2 #obtengo iqr
print("iqr:",iqr_peso_usd_m2)
print("q1:",q1_usd_m2)
print("q3:",q3_usd_m2)
median_price_usd_m2 = df_aux.price_usd_per_m2.median()
print("median:",median_price_usd_m2)


left_bound = median_price_usd_m2 -(1.5 * iqr_peso_usd_m2) 
right_bound = median_price_usd_m2 +(1.5 * iqr_peso_usd_m2) 


#df_aux.price_usd_per_m2[(np.abs(stats.zscore(df_aux.price_usd_per_m2)) < 3).all(axis=1)]

#print(left_bound,right_bound)
right_outliers = df_aux.price_usd_per_m2[np.abs(df_aux.price_usd_per_m2) > right_bound]
left_outliers = df_aux.price_usd_per_m2[np.abs(df_aux.price_usd_per_m2) < left_bound]
#left_outliers

print("Valor Left:",left_bound," Cantidad de outliers:",len(left_outliers))
print("Valor Right:",right_bound," Cantidad de outliers:",len(right_outliers))
#print(df_aux.price_usd_per_m2.describe())
df_aux = df_aux.drop(right_outliers.index)


right_outliers
#df_aux.iloc[57]

n, bins, patches = plt.hist(x=df_aux.price_usd_per_m2, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# iqr: 1268.2299465240642
# q1: 1218.1818181818182
# q3: 2486.4117647058824
# median: 1800.0
# Valor Left: -102.3449197860964  Cantidad de outliers: 0
# Valor Right: 3702.3449197860964  Cantidad de outliers: 4452
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_base.py:3610: MatplotlibDeprecationWarning:
# The `ymax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `top` instead.
#   alternative='`top`', obj_type='argument')
# (0.0, 1850.0)

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.scatter(df.surface_total_in_m2, df.price)
ax.set_xlabel('superficie total')
ax.set_ylabel('precio total')
plt.show()

# %%
# 1
# Relacion entre precio, cantidad de 
#         habitaciones y metros cuadrados cubiertos: Para saber en que punto tiene incidencia la cantidad de habitaciones

provincias = df.groupby("state_name").mean()
print(provincias)
barrios = df.groupby("place_name").mean()
print("cantidad de barrios:",len(barrios))
# Out:
#                                 Unnamed: 0   geonames_id        lat  \
# state_name
# Bs.As. G.B.A. Zona Norte      57403.871557  3.432958e+06 -34.461298
# Bs.As. G.B.A. Zona Oeste      45997.683330  3.453478e+06 -34.644503
# Bs.As. G.B.A. Zona Sur        67393.747348  3.433987e+06 -34.803279
# Buenos Aires Costa Atlántica  47590.422646  3.455397e+06 -37.820371
# Buenos Aires Interior         47598.473592  3.618603e+06 -36.892797
# Capital Federal               61151.927095  3.528152e+06 -34.601818
# Catamarca                     35278.592593  3.845838e+06 -28.465495
# Chaco                         49302.105263  3.538969e+06 -27.452741
# Chubut                        83694.015444  3.852432e+06 -43.758762
# Corrientes                    86664.902230  3.433078e+06 -27.638352
# Córdoba                       74868.553733  3.855880e+06 -31.460336
# Entre Ríos                    53147.934959  3.461734e+06 -31.960400
# Formosa                       89237.615385  3.433898e+06        NaN
# Jujuy                         54620.461538  3.837238e+06 -24.195935
# La Pampa                      72585.840764  3.844151e+06 -36.590159
# La Rioja                      84007.500000  3.844864e+06 -29.388298
# Mendoza                       62680.371512  3.842979e+06 -33.176096
# Misiones                      46016.368534  3.430246e+06 -27.563439
# Neuquén                       54517.361528  3.847076e+06 -39.270532
# Río Negro                     58191.438119  3.841105e+06 -40.448501
# Salta                         45917.338129  3.840418e+06 -24.880056
# San Juan                      44311.400000  3.838077e+06 -31.797697
# San Luis                      61732.611111  3.841378e+06 -33.030222
# Santa Cruz                    48093.950000  4.002762e+06 -46.291738
# Santa Fe                      68527.026543  3.838073e+06 -32.674666
# Santiago Del Estero           61437.500000  3.835084e+06 -27.493565
# Tierra Del Fuego              38428.387097  3.836585e+06 -54.050407
# Tucumán                       75169.863501  3.835372e+06 -27.036145
#
#                                     lon         price  \
# state_name
# Bs.As. G.B.A. Zona Norte     -58.655971  4.578555e+05
# Bs.As. G.B.A. Zona Oeste     -58.638025  1.924085e+05
# Bs.As. G.B.A. Zona Sur       -58.284172  2.426587e+05
# Buenos Aires Costa Atlántica -57.459391  2.377947e+05
# Buenos Aires Interior        -60.432004  3.329714e+05
# Capital Federal              -58.436237  3.829522e+05
# Catamarca                    -65.782725  9.269615e+05
# Chaco                        -59.029074  1.508889e+06
# Chubut                       -66.281183  4.017531e+05
# Corrientes                   -58.103935  2.210756e+05
# Córdoba                      -64.268148  9.387552e+05
# Entre Ríos                   -59.701818  9.131019e+05
# Formosa                             NaN  1.131584e+06
# Jujuy                        -65.306648  1.524900e+06
# La Pampa                     -64.191951  1.382194e+06
# La Rioja                     -67.198171  6.745000e+05
# Mendoza                      -68.755104  2.064183e+06
# Misiones                     -55.928710  1.466403e+06
# Neuquén                      -69.003246  1.133325e+06
# Río Negro                    -69.900676  4.725492e+05
# Salta                        -65.423517  1.653795e+06
# San Juan                     -68.280423  2.812500e+06
# San Luis                     -65.870621  7.433909e+05
# Santa Cruz                   -67.404255  1.397105e+06
# Santa Fe                     -60.704424  1.147530e+06
# Santiago Del Estero          -64.868594  3.333333e+05
# Tierra Del Fuego             -67.872552  1.617435e+06
# Tucumán                      -65.210019  1.867673e+06
#
#                               price_aprox_local_currency  price_aprox_usd  \
# state_name
# Bs.As. G.B.A. Zona Norte                    5.722413e+06    324317.123170
# Bs.As. G.B.A. Zona Oeste                    2.956259e+06    167545.648499
# Bs.As. G.B.A. Zona Sur                      3.503416e+06    198555.715572
# Buenos Aires Costa Atlántica                2.530768e+06    143430.988472
# Buenos Aires Interior                       3.233355e+06    183249.996582
# Capital Federal                             4.757013e+06    269603.182879
# Catamarca                                   1.280059e+07    725471.707308
# Chaco                                       3.151017e+06    178583.551389
# Chubut                                      6.040386e+06    342338.181524
# Corrientes                                  3.650590e+06    206896.786681
# Córdoba                                     3.592848e+06    203624.244417
# Entre Ríos                                  2.613394e+06    148113.819692
# Formosa                                     1.119779e+06     63463.367586
# Jujuy                                       5.321307e+06    301584.442000
# La Pampa                                    1.959489e+06    111053.792222
# La Rioja                                    1.075510e+06     60954.385000
# Mendoza                                     4.405928e+06    249705.485588
# Misiones                                    2.139247e+06    121241.552299
# Neuquén                                     3.871717e+06    219429.090401
# Río Negro                                   5.295576e+06    300126.180693
# Salta                                       5.518419e+06    312755.743529
# San Juan                                    5.285866e+06    299575.820000
# San Luis                                    4.980028e+06    282242.500433
# Santa Cruz                                  3.107717e+06    176129.507895
# Santa Fe                                    2.463342e+06    139609.617118
# Santiago Del Estero                         2.883612e+06    163428.393333
# Tierra Del Fuego                            3.180364e+06    180246.755161
# Tucumán                                     2.803336e+06    158878.733192
#
#                               surface_total_in_m2  surface_covered_in_m2  \
# Capital Federal               2.713475   6356.513805
# Catamarca                     3.666667           NaN
# Chaco                         4.235294   2100.000000
# Chubut                        3.166667   1000.000000
# Corrientes                    4.750000   1954.869565
# Córdoba                       4.308305   3806.878728
# Entre Ríos                    2.844444    574.080000
# Formosa                            NaN   1120.000000
# Jujuy                         4.600000           NaN
# La Pampa                      3.600000    983.333333
# La Rioja                      6.500000           NaN
# Mendoza                       4.974359  47211.173913
# Misiones                      3.573770   2500.000000
# Neuquén                       3.415042    939.944444
# Río Negro                     3.672566   1611.636364
# Salta                         4.345946   3300.000000
# San Juan                      3.000000           NaN
# San Luis                      3.714286   1990.400000
# Santa Cruz                    3.583333           NaN
# Santa Fe                      3.049315   6109.411392
# Santiago Del Estero           1.000000      1.000000
# Tierra Del Fuego              3.350000    300.000000
# Tucumán                       3.328125   2325.255556
# cantidad de barrios 1060

# %%
# 10. Obtener la cantidad de ambientes desde la descripcion
# https://gitlab.com/dsdh/properatti/issues/11

df_description_notnull = df[df.description.notnull()] # obtengo aquellos cuya descripcion es notnull
print("Cantidad de registros dataset: ",len(df))
print("Cantidad de registros description not null: ",len(df_description_notnull))


description_array = df_description_notnull.description.str.lower()
pattern_amb = re.compile("(.*) amb")

# TODO: Menos if!!
def get_ambientes(row):
    str_amb = pattern_amb.search(row) #busco pattern com ambientes
    if str_amb: # si existe
        str_amb = str_amb.group(1) #obtenego el string antes de ambientes
        result = [int(s) for s in str_amb.split() if s.isdigit()] #split del string y obtengo solo los digitos
        if result: 
            return result[-1] #retorno el ultimo digito detras de "# amb"


df_description_notnull.description.apply(get_ambientes)
df_description_notnull

# %%
mask_surfaceprop = (df['surface_total_in_m2'].notnull())& (df['surface_covered_in_m2'].notnull())
df_st = df[mask_surfaceprop]

grouped_df_st = df_st.groupby(['state_name']) #agrupo por state_name
grouped_df_st_and_sum = grouped_df_st.agg({"surface_covered_in_m2": "sum","surface_total_in_m2": "sum"}) #agrupo y sumarizo


grouped_df_st_and_sum = grouped_df_st_and_sum.rename(columns={'surface_covered_in_m2':'sum_surface_covered_in_m2',
                          'surface_total_in_m2':'sum_surface_total_in_m2'}) # renombro las columnas


def divide_total_covered(row_df_st):
    row_df_st['proportion'] = row_df_st['surface_total_in_m2'] / row_df_st['surface_covered_in_m2']
    return row_df_st

grouped_df_st.apply(divide_total_covered)
# Out:
#         Unnamed: 0 operation property_type                place_name  \
# 0                0      sell            PH                 Mataderos
# 2                2      sell     apartment                 Mataderos
# 4                4      sell     apartment                    Centro
# 6                6      sell            PH                     Munro
# 7                7      sell     apartment                  Belgrano
# 8                8      sell     apartment                  Belgrano
# 12              12      sell     apartment                  Martínez
# 13              13      sell     apartment              Palermo Soho
# 14              14      sell     apartment              Palermo Soho
# 16              16      sell            PH                 Mataderos
# 17              17      sell     apartment            Barrio El Golf
# 18              18      sell         house                     Tigre
# 19              19      sell     apartment                   Palermo
# 20              20      sell         house            Villa Giardino
# 21              21      sell     apartment                   Palermo
# 22              22      sell         house         General Rodríguez
# 23              23      sell     apartment                     Pilar
Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Esta...    Argentina
# 28      |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Cast...    Argentina
# 29                     |Argentina|Capital Federal|Flores|    Argentina
# 30             |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 31      |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 32                            |Argentina|Córdoba|Córdoba|    Argentina
# 33      |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 34      |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 35                      |Argentina|Capital Federal|Boedo|    Argentina
# 36       |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar|    Argentina
# ...                                                   ...          ...
# 121122                                |Argentina|Córdoba|    Argentina
# 121123  |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Cast...    Argentina
# 121124                        |Argentina|Capital Federal|    Argentina
# 121125                        |Argentina|Capital Federal|    Argentina
# 121127  |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Cast...    Argentina
# 121131               |Argentina|Capital Federal|Recoleta|    Argentina
# 121132  |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 121135  |Argentina|Capital Federal|Palermo|Palermo Hol...    Argentina
# 121136  |Argentina|Capital Federal|Palermo|Palermo Hol...    Argentina
# 121137  |Argentina|Capital Federal|Palermo|Palermo Hol...    Argentina
# 121138               |Argentina|Capital Federal|Saavedra|    Argentina
# 121139  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121141               |Argentina|Bs.As. G.B.A. Zona Norte|    Argentina
# 121143  |Argentina|Bs.As. G.B.A. Zona Norte|San Fernando|    Argentina
# 121145  |Argentina|Bs.As. G.B.A. Zona Sur|Lomas de Zam...    Argentina
# 121146                |Argentina|Capital Federal|Palermo|    Argentina
# 121147               |Argentina|Capital Federal|Belgrano|    Argentina
# 121153           |Argentina|Capital Federal|Barrio Norte|    Argentina
# 121154  |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|La ...    Argentina
# 121157               |Argentina|Capital Federal|Belgrano|    Argentina
# 121158               |Argentina|Capital Federal|Recoleta|    Argentina
# 121211  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121212  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121213  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121214    |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|    Argentina
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 0                    Capital Federal    3430787.0
# 2                    Capital Federal    3430787.0
# 4       Buenos Aires Costa Atlántica    3435548.0
# 6           Bs.As. G.B.A. Zona Norte    3430511.0
# 7                    Capital Federal    3436077.0
# 8                    Capital Federal    3436077.0
# 12          Bs.As. G.B.A. Zona Norte    3430813.0
# 13                   Capital Federal    3430234.0
# 14                   Capital Federal    3430234.0
# 16                   Capital Federal    3430787.0
# 17          Bs.As. G.B.A. Zona Norte          NaN
# 18          Bs.As. G.B.A. Zona Norte    3427753.0
# 19                   Capital Federal    3430234.0
# 20                           Córdoba    3832729.0
# 21                   Capital Federal    3430234.0
# 22          Bs.As. G.B.A. Zona Oeste    3433780.0
# 23          Bs.As. G.B.A. Zona Norte          NaN
# 24          Bs.As. G.B.A. Zona Oeste    3435607.0
# 25          Bs.As. G.B.A. Zona Oeste    3435607.0
# 26          Bs.As. G.B.A. Zona Norte          NaN
# 27          Bs.As. G.B.A. Zona Norte          NaN
# 28          Bs.As. G.B.A. Zona Oeste    3435607.0
# 29                   Capital Federal    3433918.0
# 30          Bs.As. G.B.A. Zona Norte    3429979.0
# 31          Bs.As. G.B.A. Zona Norte    3430511.0
# 32                           Córdoba    3860259.0
# 33          Bs.As. G.B.A. Zona Norte          NaN
# 34          Bs.As. G.B.A. Zona Norte    3430511.0
# 35                   Capital Federal    3436003.0
# 36          Bs.As. G.B.A. Zona Norte          NaN
# ...                              ...          ...
# 121122                       Córdoba    3860255.0
# 121123      Bs.As. G.B.A. Zona Oeste    3435607.0
# 121124               Capital Federal    3433955.0
# 121125               Capital Federal    3433955.0
# 121127      Bs.As. G.B.A. Zona Oeste    3435607.0
# 121131               Capital Federal    3429595.0
# 121132      Bs.As. G.B.A. Zona Norte          NaN
# 121135               Capital Federal          NaN
# 121136               Capital Federal          NaN
# 121137               Capital Federal          NaN
# 121138               Capital Federal    3429422.0
# 121139  Buenos Aires Costa Atlántica          NaN
# 121141      Bs.As. G.B.A. Zona Norte    3435907.0
# 121143      Bs.As. G.B.A. Zona Norte    3429088.0
# 121145        Bs.As. G.B.A. Zona Sur    3436152.0
# 121146               Capital Federal    3430234.0
# 121147               Capital Federal    3436077.0
# 121153               Capital Federal    3436109.0
# 121154        Bs.As. G.B.A. Zona Sur    3432039.0
# 121157               Capital Federal    3436077.0
# 121158               Capital Federal    3429595.0
# 121211      Bs.As. G.B.A. Zona Norte    3436508.0
# 121212      Bs.As. G.B.A. Zona Norte    3436508.0
# 121213      Bs.As. G.B.A. Zona Norte    3430813.0
# 121214      Bs.As. G.B.A. Zona Norte    3428983.0
# 121215               Capital Federal    3436077.0
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
# 121219               Capital Federal    3433955.0
#
#                               lat-lon        lat     ...      \
# 0             -34.6618237,-58.5088387 -34.661824     ...
# 2             -34.6522615,-58.5229825 -34.652262     ...
# 4             -38.0026256,-57.5494468 -38.002626     ...
# 6             -34.5329567,-58.5217825 -34.532957     ...
# 7              -34.5598729,-58.443362 -34.559873     ...
# 8              -34.5598729,-58.443362 -34.559873     ...
# 12            -34.4860195,-58.5038139 -34.486019     ...
# 13                                NaN        NaN     ...
# 14                                NaN        NaN     ...
# 16      -34.6523561177,-58.5016239381 -34.652356     ...
# 17      -34.4087174767,-58.6343892841 -34.408717     ...
# 18             -34.425087,-58.5796585 -34.425087     ...
# 19       -34.580503566,-58.4058744847 -34.580504     ...
# 20            -31.0529852,-64.4991278 -31.052985     ...
# 21             -34.590926,-58.4116653 -34.590926     ...
# 22      -34.6501160392,-58.9660339715 -34.650116     ...
# 23                                NaN        NaN     ...
# 24      -34.6511052674,-58.6438613116 -34.651105     ...
# 25      -34.6511052674,-58.6438613116 -34.651105     ...
# 26            -34.3640924,-58.6897345 -34.364092     ...
# 27            -34.4794863,-58.9845412 -34.479486     ...
# 28      -34.6511052674,-58.6438613116 -34.651105     ...
# 29      -34.6351179478,-58.4739639408 -34.635118     ...
# 30              -34.453857,-58.840181 -34.453857     ...
# 31      -34.5417881941,-58.5403487953 -34.541788     ...
# 32            -31.4053736,-64.1562667 -31.405374     ...
# 33      -34.4087174767,-58.6343892841 -34.408717     ...
# 34            -34.5272528,-58.5128766 -34.527253     ...
# 35      -34.6217693287,-58.4221081951 -34.621769     ...
# 36            -34.4630984,-58.9021989 -34.463098     ...
# ...                               ...        ...     ...
# 121122                            NaN        NaN     ...
# 121123                            NaN        NaN     ...
# 121124                            NaN        NaN     ...
# 121125  -34.6370141711,-58.4331771353 -34.637014     ...
# 121127                            NaN        NaN     ...
# 121131  -34.5906282762,-58.3975392609 -34.590628     ...
# 121132                            NaN        NaN     ...
# 121135                            NaN        NaN     ...
# 121136                            NaN        NaN     ...
# 121137                            NaN        NaN     ...
# 121138                            NaN        NaN     ...
# 121139                            NaN        NaN     ...
# 121141                            NaN        NaN     ...
# 121143                            NaN        NaN     ...
# 121145                            NaN        NaN     ...
# 121146                            NaN        NaN     ...
# 121147                            NaN        NaN     ...
# 121153  -34.5992135511,-58.4025191971 -34.599214     ...
# 121154                            NaN        NaN     ...
# 121157                            NaN        NaN     ...
# 121158   -34.587425443,-58.3973722534 -34.587425     ...
# 121211                            NaN        NaN     ...
# 121212                            NaN        NaN     ...
# 121213                            NaN        NaN     ...
# 121214                            NaN        NaN     ...
# 121215                            NaN        NaN     ...
# 121216                            NaN        NaN     ...
# 121217  -34.5706388726,-58.4755963355 -34.570639     ...
# 121218                            NaN        NaN     ...
# 121219                            NaN        NaN     ...
#
#         price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0            1127.272727   1550.000000   NaN    NaN       NaN
# 2            1309.090909   1309.090909   NaN    NaN       NaN
# 4            1828.571429   1828.571429   NaN    NaN       NaN
# 6            1226.415094   1666.666667   NaN    NaN       NaN
# 7            3066.666667   3450.000000   NaN    NaN       NaN
# 8            3000.000000   3250.000000   NaN    NaN       NaN
# 12           2948.717949   3194.444444   NaN    NaN       NaN
# 13           2234.000000   3723.333333   NaN    1.0       NaN
# 14           3521.428571   4770.967742   NaN    1.0       NaN
# 16           1707.142857   2438.775510   NaN    4.0       NaN
# 17           1789.772727   4038.461538   NaN    3.0       NaN
# 18           2111.111111   2111.111111   NaN    NaN       NaN
# 19           3365.384615   3645.833333   NaN    3.0       NaN
# 20                   NaN           NaN   NaN    NaN       NaN
# 21           2292.372881   3705.479452   NaN    4.0       NaN
# 22           1450.000000   1450.000000   NaN    NaN       NaN
# 16      http://www.properati.com.ar/15bpj_venta_ph_mat...
# 17      http://www.properati.com.ar/15bpl_venta_depart...
# 18      http://www.properati.com.ar/15bq1_venta_casa_t...
# 19      http://www.properati.com.ar/15bq8_venta_depart...
# 20      http://www.properati.com.ar/15bqb_venta_casa_v...
# 21      http://www.properati.com.ar/15bqd_venta_depart...
# 22      http://www.properati.com.ar/15bqj_venta_casa_g...
# 23      http://www.properati.com.ar/15bqt_venta_depart...
# 24      http://www.properati.com.ar/15bqu_venta_depart...
# 25      http://www.properati.com.ar/15bqv_venta_depart...
# 26      http://www.properati.com.ar/15bqx_venta_casa_b...
# 27      http://www.properati.com.ar/15bqz_venta_casa_e...
# 28      http://www.properati.com.ar/15br2_venta_depart...
# 29      http://www.properati.com.ar/15br4_venta_depart...
# 30      http://www.properati.com.ar/15bre_venta_casa_p...
# 31      http://www.properati.com.ar/15brt_venta_casa_m...
# 32      http://www.properati.com.ar/15bry_venta_depart...
# 33      http://www.properati.com.ar/15bs1_venta_depart...
# 34      http://www.properati.com.ar/15bsc_venta_ph_mun...
# 35      http://www.properati.com.ar/15bsq_venta_depart...
# 36      http://www.properati.com.ar/15bsr_venta_casa_p...
# ...                                                   ...
# 121122  http://www.properati.com.ar/1cj46_venta_depart...
# 121123  http://www.properati.com.ar/1cj48_venta_depart...
# 121124  http://www.properati.com.ar/1cj49_venta_depart...
# 121125  http://www.properati.com.ar/1cj4a_venta_local_...
# 121127  http://www.properati.com.ar/1cj4d_venta_depart...
# 121131  http://www.properati.com.ar/1cj4i_venta_depart...
# 121132  http://www.properati.com.ar/1cj4j_venta_depart...
# 121135  http://www.properati.com.ar/1cj4s_venta_depart...
# 121136  http://www.properati.com.ar/1cj4t_venta_depart...
# 121137  http://www.properati.com.ar/1cj4u_venta_depart...
# 121138  http://www.properati.com.ar/1cj4w_venta_depart...
# 121139  http://www.properati.com.ar/1cj4x_venta_depart...
# 121141  http://www.properati.com.ar/1cj4z_venta_casa_b...
# 121143  http://www.properati.com.ar/1cj52_venta_depart...
# 121145  http://www.properati.com.ar/1cj54_venta_casa_b...
# 121146  http://www.properati.com.ar/1cj56_venta_depart...
# 121147  http://www.properati.com.ar/1cj57_venta_casa_b...
# 121153  http://www.properati.com.ar/1cj5g_venta_depart...
# 121154  http://www.properati.com.ar/1cj5k_venta_casa_l...
# 121157  http://www.properati.com.ar/1cj5q_venta_depart...
# 121158  http://www.properati.com.ar/1cj5s_venta_depart...
# 121211  http://www.properati.com.ar/1cj9y_venta_depart...
# 121212  http://www.properati.com.ar/1cj9z_venta_casa_a...
# 121213  http://www.properati.com.ar/1cja0_venta_casa_m...
# 121214  http://www.properati.com.ar/1cja1_venta_local_...
# 121215  http://www.properati.com.ar/1cja2_venta_depart...
# 121216  http://www.properati.com.ar/1cja6_venta_casa_b...
# 121217  http://www.properati.com.ar/1cja7_venta_depart...
# 121218  http://www.properati.com.ar/1cja8_venta_depart...
# 121219  http://www.properati.com.ar/1cjaa_venta_depart...
#
#                                               description  \
