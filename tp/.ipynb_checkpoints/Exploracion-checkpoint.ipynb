# %% [markdown]
# # Exploracion
#
# ## 1. Exploracion y analisis de datos

# %%
import pandas as pd
import numpy as np
import numpy as np
import re
import seaborn as sns
from scipy import stats
import math
import operator
import plotly
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go
from plotly.graph_objs import *
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.figure_factory as ff#visualization
from plotly.offline import *

# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = 10, 10
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV, ElasticNetCV
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
# df = pd.read_csv('df_alumnos.csv')
df = pd.read_csv('df_alumnos.csv', index_col='alumno')
df.sample(5)
# Out:
#         dias_inscripcion  cant_cambios_plan  cant_inasistencias  \
# alumno
# 209127                87                  1                 1.0
# 561909               252                  1                 NaN
# 206626                87                  1                 7.0
# 110233              1448                  1                 5.0
# 550573               417                  1                 NaN
#
#         cant_inscr_fuera_termino  cant_dias_inscripcion_ult_plan  promedio  \
# alumno
# 209127                       NaN                            1649      3.50
# 561909                       NaN                             252      4.25
# 206626                       1.0                            2065      5.58
# 110233                       NaN                            3527      7.02
# 550573                       NaN                            1596      8.58
#
#         cant_aprobados  cant_desaprobados costeo_estudios_beca  \
# alumno
# 209127             3.0                5.0                    N
# 561909             3.0                1.0                    N
# 206626            15.0                4.0                    N
# 110233            50.0                6.0                    S
# 550573            12.0                NaN                    N
#
#        costeo_estudios_familiar   ...    propuesta_academica  \
# alumno                            ...
# 209127                        S   ...                    103
# 561909                        S   ...                     40
# 206626                        S   ...                    103
# 110233                        S   ...                     86
# 550573                        S   ...                    238
#
#                 propuesta_academica_descripcion estudio_alcanzado_padre  \
# alumno
# 209127  Traductorado Público Nacional de Inglés                     NaN
# 561909                         Ingeniería Civil                    11.0
# 206626  Traductorado Público Nacional de Inglés                     NaN
# 110233                     Ingeniería Biomédica                     NaN
# 550573                   Licenciatura en Teatro                     NaN
#
#        estudio_alcanzado_madre trabajo_existe_madre trabajo_hace_madre  \
# alumno
# 209127                     NaN                  NaN                NaN
# 561909                     8.0                  3.0                NaN
# 206626                     NaN                  NaN                NaN
# 110233                     NaN                  NaN                NaN
# 550573                     NaN                  NaN                NaN
#
#         trabajo_existe_padre trabajo_hace_padre  trabajo_existe_alumno  \
# alumno
# 209127                   NaN                NaN                    NaN
# 561909                   1.0                3.0                    NaN
# 206626                   NaN                NaN                    NaN
# 110233                   NaN                NaN                    NaN
# 550573                   NaN                NaN                    NaN
#
#         regular
# alumno
# 209127        S
# 561909        S
# 206626        S
# 110233        S
# 550573        S
#
# [5 rows x 57 columns]

# %%
df = df.replace('S',1)
df = df.replace('N',0)
df.sample(3)
# Out:
#         dias_inscripcion  cant_cambios_plan  cant_inasistencias  \
# alumno
# 237640                43                  2                 NaN
# 275281               271                  1                 2.0
# 59151                 81                  1                 NaN
#
#         cant_inscr_fuera_termino  cant_dias_inscripcion_ult_plan  promedio  \
# alumno
# 237640                       NaN                            2363      4.13
# 275281                       NaN                            2800      8.37
# 59151                        NaN                            3891      7.00
#
#         cant_aprobados  cant_desaprobados  costeo_estudios_beca  \
# alumno
# 237640             4.0                4.0                   0.0
# 275281            35.0                NaN                   0.0
# 59151              2.0                NaN                   0.0
#
#         costeo_estudios_familiar   ...     propuesta_academica  \
# alumno                             ...
# 237640                       1.0   ...                     135
# 275281                       1.0   ...                     147
# 59151                        1.0   ...                      12
#
#             propuesta_academica_descripcion estudio_alcanzado_padre  \
# alumno
# 237640                           Bioquímica                     NaN
# 275281  Licenciatura en Comunicación Social                     NaN
# 59151                          Arquitectura                     NaN
#
#         estudio_alcanzado_madre  trabajo_existe_madre  trabajo_hace_madre  \
# alumno
# 237640                      NaN                   NaN                 NaN
# 275281                      NaN                   NaN                 NaN
# 59151                       NaN                   NaN                 NaN
#
#         trabajo_existe_padre  trabajo_hace_padre  trabajo_existe_alumno  \
# alumno
# 237640                   NaN                 NaN                    NaN
# 275281                   NaN                 NaN                    1.0
# 59151                    NaN                 NaN                    NaN
#
#         regular
# alumno
# 237640        1
# 275281        1
# 59151         1
#
# [3 rows x 57 columns]

# %%
df.describe()
# Out:
#        dias_inscripcion  cant_cambios_plan  cant_inasistencias  \
# count     162316.000000      162316.000000        45008.000000
# mean         555.127738           1.051751           36.077897
# std          720.504863           0.221524           79.436154
# min           27.000000           1.000000            0.000000
# 25%          141.000000           1.000000            2.000000
# 50%          271.000000           1.000000            5.000000
# 75%          532.000000           1.000000           13.000000
# max         4995.000000           2.000000          540.000000
#
#        cant_inscr_fuera_termino  cant_dias_inscripcion_ult_plan  \
# count              12131.000000                   162316.000000
# mean                   2.274751                     2395.742699
# std                    2.092094                     1365.533163
# min                    1.000000                       61.000000
# 25%                    1.000000                     1268.000000
# 50%                    1.000000                     2363.000000
# 75%                    2.000000                     3526.000000
# max                   17.000000                    11150.000000
#
#             promedio  cant_aprobados  cant_desaprobados  costeo_estudios_beca  \
# count  162316.000000   150450.000000      110660.000000         157177.000000
# mean        5.390587       11.693061           4.917884              0.033987
# std         1.864358       12.306521           5.540781              0.181197
# min         0.000000        1.000000           1.000000              0.000000
# 25%         4.000000        2.000000           1.000000              0.000000
# 50%         5.270000        6.000000           3.000000              0.000000
# 75%         6.820000       18.000000           6.000000              0.000000
# max        10.000000       60.000000          95.000000              1.000000
#
#        costeo_estudios_familiar      ...        nivel_estudio_alcanzado  \
# count             162038.000000      ...                  150245.000000
# mean                   0.775158      ...                       3.025711
# std                    0.417480      ...                       0.207608
# min                    0.000000      ...                       1.000000
# 25%                    1.000000      ...                       3.000000
# 50%                    1.000000      ...                       3.000000
# 75%                    1.000000      ...                       3.000000
# max                    1.000000      ...                       7.000000
#
#        propuesta_academica  estudio_alcanzado_padre  estudio_alcanzado_madre  \
# count        162316.000000             44779.000000             46255.000000
# mean            187.569451                 7.103106                 7.710172
# std             114.917785                 3.329343                 3.128697
# min               1.000000                 1.000000                 1.000000
# 25%              87.000000                 4.000000                 5.000000
# 50%             179.000000                 5.000000                 9.000000
# 75%             314.000000                11.000000                11.000000
# max             335.000000                13.000000                14.000000
#
#        trabajo_existe_madre  trabajo_hace_madre  trabajo_existe_padre  \
# count          41306.000000        28632.000000          38821.000000
# mean               1.608386            2.613614              1.452822
# std                1.030174            0.648758              1.010797
# min                1.000000            1.000000              1.000000
# 25%                1.000000            2.000000              1.000000
# 50%                1.000000            3.000000              1.000000
# 75%                2.000000            3.000000              1.000000
# max                4.000000            4.000000              4.000000
#
#        trabajo_hace_padre  trabajo_existe_alumno        regular
# count        30967.000000           56958.000000  162316.000000
# mean             2.391449               1.000263       0.927469
# std              0.771825               0.020949       0.259366
# min              1.000000               1.000000       0.000000
# 25%              2.000000               1.000000       1.000000
# 50%              3.000000               1.000000       1.000000
# 75%              3.000000               1.000000       1.000000
# max              4.000000               3.000000       1.000000
#
# [8 rows x 52 columns]

# %%
df.columns
# Out:
# Index(['dias_inscripcion', 'cant_cambios_plan', 'cant_inasistencias',
#        'cant_inscr_fuera_termino', 'cant_dias_inscripcion_ult_plan',
#        'promedio', 'cant_aprobados', 'cant_desaprobados',
#        'costeo_estudios_beca', 'costeo_estudios_familiar',
#        'costeo_estudios_plan_social', 'costeo_estudios_trabajo', 'sexo',
#        'beca', 'tiene_pc_casa', 'tiene_internet_casa', 'nivel_idioma_ingles',
#        'deportes', 'trabajo_hace', 'trabajo_carrera', 'estado_civil',
#        'situacion_madre', 'situacion_padre', 'cantidad_hijos',
#        'cobertura_salud', 'periodo_lectivo_localidad', 'procedencia_localidad',
#        'vive_con', 'institucion_mot_economico', 'institucion_mot_prestigio',
#        'institucion_mot_difusion', 'institucion_mot_recomendacion_amigos',
#        'institucion_mot_recomendacion_estudiantes',
#        'institucion_mot_sistema_ingreso', 'institucion_mot_ubicacion',
#        'propuesta_mot_vocacion', 'propuesta_mot_sugerencia_familiar',
#        'propuesta_mot_reconocimiento_social',
#        'propuesta_mot_insercion_laboral', 'propuesta_mot_perfil_profesional',
#        'propuesta_mot_mejora_economica', 'propuesta_mot_util_sociedad',
#        'propuesta_mot_otros', 'titulo_sec', 'descripcion_titulo_sec',
#        'colegio', 'nivel_estudio_alcanzado', 'propuesta_academica',
#        'propuesta_academica_descripcion', 'estudio_alcanzado_padre',
#        'estudio_alcanzado_madre', 'trabajo_existe_madre', 'trabajo_hace_madre',
#        'trabajo_existe_padre', 'trabajo_hace_padre', 'trabajo_existe_alumno',
#        'regular'],
#       dtype='object')

# %% [markdown]
# #### Creo columna de rangos de promedio

# %%
bins = [0, 2, 4, 6, 8, 10]
names = ['0-2', '2-4', '4-6', '6-8', '8-10']

df['promedio_range'] = pd.cut(df.promedio, bins, labels=names)

# %% [markdown]
# #### Creo la columna de rangos de inasistencias

# %%
bins = [0, 20, 50, 100, 200, 500]
names = ['0-20', '20-50', '50-100', '100-200', '200-500']

df['cant_inasistencias_range'] = pd.cut(df.promedio, bins, labels=names)

# %%
df.cant_inasistencias.describe()
# Out:
# count    45008.000000
# mean        36.077897
# std         79.436154
# min          0.000000
# 25%          2.000000
# 50%          5.000000
# 75%         13.000000
# max        540.000000
# Name: cant_inasistencias, dtype: float64

# %%
def camel_to_snake(column_name):
    """
    Converts a string that is camelCase into snake_case
    """
    s1 = re.sub('(.)([A-Z][a-z]+)', r'\1_\2', column_name)
    return re.sub('([a-z0-9])([A-Z])', r'\1_\2', s1).lower()

#Define Data

df.columns = [camel_to_snake(col) for col in df.columns]
df.sample(3)
# Out:
#         dias_inscripcion  cant_cambios_plan  cant_inasistencias  \
# alumno
# 706920               448                  1                 3.0
# 799847               141                  1                 NaN
# 993338               527                  1                58.0
#
#         cant_inscr_fuera_termino  cant_dias_inscripcion_ult_plan  promedio  \
# alumno
# 706920                       NaN                             606       4.0
# 799847                       NaN                            1707       8.0
# 993338                       NaN                             527       6.0
#
#         cant_aprobados  cant_desaprobados  costeo_estudios_beca  \
# alumno
# 706920             5.0                4.0                   0.0
# 799847             7.0                NaN                   0.0
# 993338             4.0                NaN                   0.0
#
#         costeo_estudios_familiar            ...             \
# alumno                                      ...
# 706920                       1.0            ...
# 799847                       1.0            ...
# 993338                       1.0            ...
#
#         estudio_alcanzado_padre  estudio_alcanzado_madre trabajo_existe_madre  \
# alumno
# 706920                     11.0                     11.0                  1.0
# 799847                      NaN                      NaN                  NaN
# 993338                     11.0                     11.0                  NaN
#
#         trabajo_hace_madre  trabajo_existe_padre  trabajo_hace_padre  \
# alumno
# 706920                 3.0                   1.0                 2.0
# 799847                 NaN                   NaN                 NaN
# 993338                 NaN                   NaN                 NaN
#
#         trabajo_existe_alumno  regular  promedio_range  \
# alumno
# 706920                    NaN        1             2-4
# 799847                    NaN        1             6-8
# 993338                    1.0        1             4-6
#
#         cant_inasistencias_range
# alumno
# 706920                      0-20
# 799847                      0-20
# 993338                      0-20
#
# [3 rows x 59 columns]

# %% [markdown]
# ### Graficos de Barra

# %%
def bar(variable, df):
    fig =df.groupby(variable).size().plot(kind='bar')
    fig.set_xlabel(variable)
    fig.set_ylabel('Cantidad de registros')
    fig.set_title('Distribución de '+variable)
    plt.draw()
    plt.savefig("graph/histogramas/"+variable+"_bar.jpg")
    plt.close('all')

# %%
bar('regular',df)
bar('sexo',df)
bar('trabajo_existe_alumno',df)
bar('estado_civil',df)
bar('promedio_range',df)
bar('nivel_estudio_alcanzado',df)
bar('trabajo_existe_padre',df)
bar('trabajo_existe_madre',df)

# %% [markdown]
# ### Funcion para generar matriz de correlaciones

# %%
df2 = df.cant_inasistencias.dropna()
df2 = df.trabajo_existe_alumno.dropna()

# df.shape
df = df.loc[df2.index]
df.shape
# Out:
# (56958, 59)

# %%
def corr_graph(df):
    fig, ax = plt.subplots(figsize=(100,100))       
    sns.heatmap(df.corr() , square=True, annot=True, ax=ax);
    ax.set_title("Correlacion")
    plt.draw()
    plt.savefig("graph/corr_graph.jpg")
    plt.close('all')

# %%
corr_graph(df)

# %% [markdown]
# ### Generar histogramas
# Genera histogramas de datos numericos dividiendo por cantidad de bins

# %%
def histogram1(variable, df, color, bins):
    fig = df[variable].hist(bins=bins, color=color)
    fig.set_xlabel(variable)
    fig.set_ylabel('Cantidad de Registros')
    fig.set_title('Distribución de '+variable)
    plt.draw()
    plt.savefig("graph/histogramas/"+variable+"_histogram1_"+str(bins)+".jpg")
    plt.clf()

# %%
histogram1('cant_desaprobados', df, 'c', 6)
histogram1('cant_aprobados', df, 'c', 6)
histogram1('cant_inasistencias', df, 'c', 6)
histogram1('cant_inscr_fuera_termino', df, 'c', 6)
histogram1('cant_cambios_plan', df, 'c', 4)

# %% [markdown]
# ### Discretizar variables en quartiles o con la mediana

# %%
def make_discrete_df(variable, df, option=4):
    """Esta funcion toma una variable, df y opcion, y retorna el df original con la nueva variable discretizada
        Options:
        2 	= Median
        4 	= Quartiles
    """
    OPT = str(option)
    VAR = str(variable)
    VAR_discrete = VAR+'_discrete'+OPT
    data = df
    data.columns = [camel_to_snake(col) for col in data.columns]
    data.rename(columns={VAR: VAR_discrete}, inplace=True)

    #Median
    if option == 2:
        median = pd.qcut(data[VAR_discrete], 2, labels=['0', '1'])
        data.rename(columns={VAR_discrete: VAR}, inplace=True)
        cols_to_keep = data.columns
        data_new = data[cols_to_keep].join(median)
        return data_new
    #Quartiles
    elif option == 4:
        quantiles = pd.qcut(data[VAR_discrete], 4, labels=['1', '2', '3', '4'])
        data.rename(columns={VAR_discrete: VAR}, inplace=True)
        cols_to_keep = data.columns
        data_new = data[cols_to_keep].join(quantiles)
        return data_new

# %%
print(df.shape)
# df = make_discrete_df('cant_inasistencias', df, 4)
# df = make_discrete_df('cant_desaprobados', df, 4)
# #df = make_discrete_df('dias_inscripcion', df, 4)
# df = make_discrete_df('cant_inscr_fuera_termino', df, 4)
print(df.shape)

# %%
# bar('cant_inasistencias_discrete4',df)
bar('cant_desaprobados_discrete4',df)

# %% [markdown]
# ### Pie Charts

# %%
plotly.tools.set_credentials_file(username='darosk88', api_key='o4Knn6HIJlzubv9dYgDw')

# %% [markdown]
# #### Dividido dataframe en regular y no regular

# %%
df_regular     = df[df["regular"] == 1]
df_not_regular = df[df["regular"] == 0]

# %%
#labels
lab = df["regular"].value_counts().keys().tolist()
lab = ['Regular','No Regular'] # paso 1 como regular 0 no regular
#values
val = df["regular"].value_counts().values.tolist()

trace = go.Pie(labels = lab ,
               values = val ,
               marker = dict(colors =  [ 'royalblue' ,'lime'],
                             line = dict(color = "white",
                                         width =  1.3)
                            ),
               rotation = 90,
               hoverinfo = "label+value+text",
               hole = .5
              )
layout = go.Layout(dict(title = "Regularidad Alumnos",
                        plot_bgcolor  = "rgb(243,243,243)",
                        paper_bgcolor = "rgb(243,243,243)",
                       )
                  )

data = [trace]
fig = go.Figure(data = data,layout = layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~darosk88/96.embed" height="525px" width="100%"></iframe>

# %%
def plot_pie(column,df_regular,df_not_regular):
    trace1 = go.Pie(values  = df_regular[column].value_counts().values.tolist(),
                    labels  = df_regular[column].value_counts().keys().tolist(),
                    hoverinfo = "label+percent+name",
                    domain  = dict(x = [0,.48]),
                    name    = "Regulares",
                    marker  = dict(line = dict(width = 2,
                                               color = "rgb(243,243,243)")
                                  ),
                    hole    = .6
                   )
    trace2 = go.Pie(values  = df_not_regular[column].value_counts().values.tolist(),
                    labels  = df_not_regular[column].value_counts().keys().tolist(),
                    hoverinfo = "label+percent+name",
                    marker  = dict(line = dict(width = 2,
                                               color = "rgb(243,243,243)")
                                  ),
                    domain  = dict(x = [.52,1]),
                    hole    = .6,
                    name    = "No regulares" 
                   )
    layout = go.Layout(dict(title = column + " distribucion de alumnos no regulares ",
                            plot_bgcolor  = "rgb(243,243,243)",
                            paper_bgcolor = "rgb(243,243,243)",
                            annotations = [dict(text = "Alumnos regulares",
                                                font = dict(size = 13),
                                                showarrow = False,
                                                x = .15, y = .5),
                                           dict(text = "Alumnos no regulares",
                                                font = dict(size = 13),
                                                showarrow = False,
                                                x = .88,y = .5
                                               )
                                          ]
                           )
                      )
    data = [trace1,trace2]
    fig  = go.Figure(data = data,layout = layout)
    return fig
    py.iplot(fig)

# %%
graph = plot_pie('cant_cambios_plan',df_regular,df_not_regular)
py.iplot(graph)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-de339135f597> in <module>()
# ----> 1 graph = plot_pie('cant_cambios_plan',df_regular,df_not_regular)
#       2 py.iplot(graph)
#
# NameError: name 'df_regular' is not defined

# %%
graph = plot_pie('promedio_range',df_regular,df_not_regular)
py.iplot(graph)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~darosk88/98.embed" height="525px" width="100%"></iframe>

# %%
graph = plot_pie('sexo',df_regular,df_not_regular)
py.iplot(graph)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~darosk88/100.embed" height="525px" width="100%"></iframe>

# %%
graph = plot_pie('cant_inasistencias_discrete4',df_regular,df_not_regular)
py.iplot(graph)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~darosk88/76.embed" height="525px" width="100%"></iframe>

# %%
df.sample(4)
# Out:
#          dias_inscripcion  cant_cambios_plan  cant_inasistencias  \
# persona
# 260708               4889                  1                 NaN
# 375196               3569                  1                 NaN
# 467755               1326                  1                 NaN
# 313849               3016                  1                 NaN
#
#          cant_inscr_fuera_termino  cant_dias_inscripcion_ult_plan  promedio  \
# persona
# 260708                        NaN                            7050       NaN
# 375196                       23.0                            3880      6.67
# 467755                        NaN                            1326       NaN
# 313849                        1.0                            7916       NaN
#
#          cant_aprobados  cant_desaprobados costeo_estudios_beca  \
# persona
# 260708              3.0                1.0                    N
# 375196              6.0                NaN                    N
# 467755              NaN                NaN                    N
# 313849              NaN                NaN                  NaN
#
#         costeo_estudios_familiar   ...    propuesta_academica  \
# persona                            ...
# 260708                         S   ...                    163
# 375196                         S   ...                    186
# 467755                         S   ...                    245
# 313849                         S   ...                    170
#
#                         propuesta_academica_descripcion  \
# persona
# 260708   Preingreso para satisfacer el art. 2 Res.D.326
# 375196       Licenciatura en Producción de Bio-Imágenes
# 467755                           INGRESO ARTES VISUALES
# 313849                                         Medicina
#
#         estudio_alcanzado_padre estudio_alcanzado_madre trabajo_existe_madre  \
# persona
# 260708                      NaN                     NaN                  NaN
# 375196                      NaN                     NaN                  NaN
# 467755                     10.0                     8.0                  4.0
# 313849                      NaN                     NaN                  NaN
#
#         trabajo_hace_madre  trabajo_existe_padre trabajo_hace_padre  \
# persona
# 260708                 NaN                   NaN                NaN
# 375196                 NaN                   NaN                NaN
# 467755                 NaN                   4.0                NaN
# 313849                 NaN                   NaN                NaN
#
#          trabajo_existe_alumno  regular
# persona
# 260708                     1.0        S
# 375196                     NaN        S
# 467755                     NaN        S
# 313849                     NaN        N
#
# [4 rows x 57 columns]

# %%
graph = plot_pie('trabajo_existe_alumno',df_regular,df_not_regular)
py.iplot(graph)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~darosk88/78.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### Grafico los nulos

# %%
# columns  = ['dias_inscripcion', 'cant_cambios_plan']
columns  = df.columns
nullcount = df[columns].isnull().sum()
notnullcount = df[columns].notnull().sum()

fig = go.Figure(data=[
    go.Bar(name='Nulls', x=columns, y=nullcount),
    go.Bar(name='NotNulls', x=columns, y=notnullcount)
])

fig.layout.update(barmode='stack')
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~darosk88/92.embed" height="525px" width="100%"></iframe>

# %%
df.shape
# Out:
# (162316, 59)
